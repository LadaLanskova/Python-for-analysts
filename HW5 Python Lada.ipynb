# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as img

# %% [markdown]
# ## Задача 1
# Постройте график
# Назовите график
# Сделайте именование оси x и оси y
# Сделайте выводы

# %% [markdown]
# ### 1.1
# Скачать данные по ссылке https://www.kaggle.com/datasets/esratmaria/house-price-dataset-with-other-information

# %%
df = pd.read_csv(r'C:\Users\Geralt\tmp\.env\Scripts\kc_house_data.csv', encoding = 'cp1251')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 1.2 Изучите стоимости недвижимости

# %%
plt.hist(df['price']/1000)
plt.title('Распределение стоимости недвижимости')
plt.xlabel('Цена дома')
plt.ylabel('Кол-во домов');

# %% [markdown]
# __Вывод:__\
# Наибольшее количество домов (~ 88% от общего количества, ~ 19 100 домов из ~ 21 600) имеет стоимость до ~ 850 тыс.
# С повышением цены количество представленных объектов резко падает.
# Так, стоимость в пределах от ~ 850 тыс. до ~ 1 млн 500 тыс. имеют ~ 11% объектов (~ 2300 домов из 21 600)
# Стоимость более ~ 2 млн 300 тыс. имеет ~ 1% домов

# %% [markdown]
# ### 1.3 Изучите распределение квадратуры жилой площади

# %%
plt.figure(figsize=(6.2, 3.4))
plt.hist(df['sqft_living'])
plt.title('Распределение жилой площади')
plt.xlabel('Жилая площадь дома')
plt.ylabel('Кол-во домов')
plt.grid(True);#добавим сетку

# %% [markdown]
# __Вывод:__\
# Наибольшее число домов (~ 49% обещего количества, ~ 10 500 домов ) - это дома с жилой площадью от ~ 1900 тыс. до ~ 3000 тыс.
# На втором месте (~ 36%, ~ 7 800 домов) - дома с жилой площадью до 2000 тыс.
# ~ 13% (~ 2 800 домов) имеют жилую площадь от ~ 3 000 тыс. до 4 100
# Доля домов с жилой площадью более ~ 4 100 не значительна.

# %% [markdown]
# ### 1.4 Изучите распределение года постройки

# %%
plt.hist(df['yr_built'])
plt.title('Распределение домов по годам постройки')
plt.xlabel('Год постройки')
plt.ylabel('Кол-во домов');

# %% [markdown]
# __Вывод:__\
# Преобладают дома от 1980 до 2015 года постройки.
# Так же значительную долю занимают дома с годом постройки от 1950 до 1980 года.
# Дома от 1900 до 1950 года постройки занимают меньшую долю.

# %% [markdown]
# ## Задача 2
# ### 2.1 Изучите распределение домов от наличия вида на набережную
# Постройте график\
# Сделайте выводы

# %%
# вариант 1 - гистограмма
df['waterfront_1'] = df['waterfront'].apply(lambda x: str(x))
plt.hist(df['waterfront_1'], bins = range(df['waterfront_1'].nunique()+1), rwidth=0.9, align = 'left')
plt.title('Распределение количества домов в зависимости от вида на набережную')
plt.xlabel('Вид на набережную: 0 - нет, 1 - есть')
plt.ylabel('Кол-во домов');

# %%
# вариант 2 - круговая диаграмма
df_w = df['waterfront'].value_counts()
plt.title('Распределение количества домов в зависимости от вида на набережную')
plt.pie(df_w.values, autopct = '%.1f%%')
plt.legend(df_w.index, title = "Вид на набережную: 0 - да; 1 - нет", loc=(0.772, 0.815));

# %% [markdown]
# __Вывод:__\
# Большинство домов не имеют вида на набережную (99,2%). Домов с видом на набережную очень мало (0,8%).

# %% [markdown]
# ### 2.2  Изучите распределение этажей домов

# %%
# вариант 1 - гистограмма, добавим подписи значений]

def addlabels(x):
    for i in range(len(x)):
        plt.text(i, x[i], x[i], ha = 'center')
        
df['floors_1'] = df['floors'].apply(lambda x: str(x))
df_sorted = df.sort_values(by=['floors_1'])   
df_f = df['floors_1'].value_counts()
df_f_frame = df_f.to_frame(name='values')
df_f_sorted = df_f_frame.sort_index()
plt.hist(df_sorted['floors_1'], bins = range(df_sorted['floors_1'].nunique()+1), rwidth=0.9, align = 'left')
plt.title('Распределение кол-ва домов в зависимости от кол-ва этажей')
plt.xlabel('Кол-во этажей')
plt.ylabel('Кол-во домов')
addlabels(df_f_sorted['values']);

# %%
# вариант 2 - столбчатая диаграмма, добавим подписи значений в %
def addlabels_1(x):
    for i in range(len(x)):
        plt.text(i, x[i], round(x[i]/len(df)*100, 1), ha = 'center')

plt.bar(df_f_sorted.index, df_f_sorted['values']);
plt.title('Распределение кол-ва домов в зависимости от кол-ва этажей (в %)')
plt.xlabel('Кол-во этажей')
plt.ylabel('Кол-во домов')
addlabels_1(df_f_sorted['values']);

# %% [markdown]
# __Вывод:__\
#     - наибольшая доля приходится на одноэтажные дома - 49,4% (10 680)\
#     - 2 этажа имеет 38,1% процент домов (8 241 дом)\
#     - ...

# %% [markdown]
# ### 2.3 Изучите распределение состояния домов

# %%
#Вариант 1 - гистограмма
        
df_c = df.sort_values(by=['condition'])
df_c['condition_1'] = df_c['condition'].apply(lambda x: str(x))
df_c_vc = df_c['condition_1'].value_counts()
df_c_frame = df_c_vс.to_frame(name='values')
df_c_sorted = df_c_frame.sort_index()
plt.hist(df_c['condition_1'], bins = range(df_c['condition_1'].nunique()+1), rwidth=0.9, align = 'left')
plt.title('Распределение кол-ва домов в зависимости от оценки состояния (в %)')
plt.xlabel('Оценка состояния')
plt.ylabel('Кол-во домов');
addlabels_1(df_c_sorted['values']);

# %%
#Вариант 2 - линейный график

plt.plot(df_c_sorted.index, df_c_sorted.values);
plt.title('Распределение кол-ва домов в зависимости от оценки состояния')
plt.xlabel('Оценка состояния')
plt.ylabel('Кол-во домов')
addlabels(df_c_sorted['values']);

# %%
df_corr = df.drop(columns=['id', 'date', 'zipcode', 'waterfront_1', 'floors_1'])

# %%
# 1 вариант - рисуем матрицу корелляций
df_corr = df.drop(columns=['id', 'date', 'zipcode', 'waterfront_1', 'floors_1'])#удаляем столбцы типа object
corr = df_corr.corr()
corr.style.background_gradient(cmap='coolwarm').format(precision = 2)
# Out:
# <style type="text/css">
# #T_d8643_row0_col0, #T_d8643_row1_col1, #T_d8643_row2_col2, #T_d8643_row3_col3, #T_d8643_row4_col4, #T_d8643_row5_col5, #T_d8643_row6_col6, #T_d8643_row7_col7, #T_d8643_row8_col8, #T_d8643_row9_col9, #T_d8643_row10_col10, #T_d8643_row11_col11, #T_d8643_row12_col12, #T_d8643_row13_col13, #T_d8643_row14_col14, #T_d8643_row15_col15, #T_d8643_row16_col16, #T_d8643_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d8643_row0_col1, #T_d8643_row15_col17 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_d8643_row0_col2, #T_d8643_row10_col12, #T_d8643_row16_col0 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_d8643_row0_col3 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_d8643_row0_col4, #T_d8643_row6_col16, #T_d8643_row12_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_d8643_row0_col5 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_d8643_row0_col6, #T_d8643_row1_col0, #T_d8643_row4_col10 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_d8643_row0_col7, #T_d8643_row1_col9, #T_d8643_row1_col11 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_d8643_row0_col8, #T_d8643_row14_col0, #T_d8643_row15_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_d8643_row0_col9, #T_d8643_row2_col9 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_d8643_row0_col10, #T_d8643_row9_col0 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_d8643_row0_col11 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_d8643_row0_col12, #T_d8643_row9_col7, #T_d8643_row15_col5 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_
{
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_d8643_row5_col11, #T_d8643_row6_col1, #T_d8643_row8_col2, #T_d8643_row8_col3, #T_d8643_row8_col5, #T_d8643_row8_col9, #T_d8643_row8_col10, #T_d8643_row8_col12, #T_d8643_row8_col16, #T_d8643_row11_col15,

# %% [markdown]
# 1. Для того, что бы оценить, от каких факторов зависит цена, посторим матрицу корреляций и посмотрим на коэффиценты корреляции в столбце 'price' и увидим, что цена наиболее сильно коррелирует со следующими факторами в порядке убывания:
# - жилая площадь,
# - оценка дома (grade),
# - общая площадь,
# - кв. метры жилой площади у 15 соседей (sqft_living15),
# - количество ванных комнат.
#
# __Обязательно нужно помнить про недостатки коэффициента корееляции:__
# - цена недвижимости может зависеть от какого-то фактора нелинейно, расти по экспоненте, изменяться по параболе, по гипрболе
# - может быть еще неучтенный фактор (третья величина), влияющая на обе исследуемые величины

# %%
#нарисуем распределение цены по географии с применением точечного графика
california_map = img.imread('san_bernardino_map_california.jpg')
min_long = -122.6
max_long = -121.3
min_lat = 47.1
max_lat = 47.8

plt.figure(figsize = (30, 10))
sc = plt.scatter(df['long'], df['lat'], alpha=0.5, c=df['price'])
plt.imshow(california_map, extent=[min_long, max_long, min_lat, max_lat], alpha=0.5);

# %% [markdown]
# Точечный график распределения цены по карте не очень показателен, т.к. по данным выборки цена дома имеет слабую  корреляцию с координатами

# %%
# Для оценки общего разброса цены домов построим "ящик с усами"
df['price_r'] = (df['price']/1000).round(decimals = 2)
plt.boxplot(df['price_r'])
plt.xticks([])
plt.title('Разброс цены домов')
plt.ylabel('Цена дома, тыс.')
plt.grid(True);

# %% [markdown]
# График "ящик с усами" показывает нам сильный резброс цены домов.
# Минимальная цена - 75 тыс. (это мы уже знаем из анализа данных).
# 50% домов имеют цену в диапазоне от ~ 350 до 700 тыс.
# Все объекты с ценой более 1 млн с небольшим по графику попадают в аномальные выборосы.

# %%
figure, axis = plt.subplots(2, 3, figsize=(12,6))

df_fl_1 = df[df['floors'] == 1]
df_fl_15 = df[df['floors'] == 1.5]
df_fl_2 = df[df['floors'] == 2]
df_fl_25 = df[df['floors'] == 2.5]
df_fl_3 = df[df['floors'] == 3]
df_fl_35 = df[df['floors'] == 3.5]

# Одноэтажные дома
axis[0, 0].boxplot(df_fl_1['price_r'])
axis[0, 0].set_title("Один этаж")
axis[0, 0].xaxis.set_ticks([])

# Полутораэтажные дома
axis[0, 1].boxplot(df_fl_15['price_r'])
axis[0, 1].set_title("1,5 этажа")
axis[0, 1].xaxis.set_ticks([])

# Двухэтажные дома
axis[0, 2].boxplot(df_fl_2['price_r'])
axis[0, 2].set_title("Два этажа")
axis[0, 2].xaxis.set_ticks([])

# 2,5-этажные дома
axis[1, 0].boxplot(df_fl_25['price_r'])
axis[1, 0].set_title("2,5 этажа")
axis[1, 0].xaxis.set_ticks([])
  
# Трехэтажные дома
axis[1, 1].boxplot(df_fl_3['price_r'])
axis[1, 1].set_title("Три этажа")
axis[1, 1].xaxis.set_ticks([])

#3,5-этажные дома
axis[1, 2].boxplot(df_fl_35['price_r'])
axis[1, 2].set_title("3,5 этажа")
axis[1, 2].xaxis.set_ticks([]);

# %% [markdown]
# "Ящик с усами" для домов с разной этажностью позволяет оценить разброс цен в разрезе домов с разным количеством этажей.
# Даже для домов одинаковой этажности мы видим достаточно большой разброс цен и много "аномальных выбросов".
